# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
EP_Data = pd.read_csv("/content/Regrerssion_energy_production_data (1).csv")
EP_Data
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9568 rows x 5 columns]

# %%
EP_Data.shape
# Out:
# (9568, 5)

# %%
EP_Data.columns
# Out:
# Index(['temperature', 'exhaust_vacuum', 'amb_pressure', 'r_humidity',
#        'energy_production'],
#       dtype='object')

# %%
EP_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature        9568 non-null   float64
#  1   exhaust_vacuum     9568 non-null   float64
#  2   amb_pressure       9568 non-null   float64
#  3   r_humidity         9568 non-null   float64
#  4   energy_production  9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
EP_Data.isna().sum()
# Out:
# temperature          0
# exhaust_vacuum       0
# amb_pressure         0
# r_humidity           0
# energy_production    0
# dtype: int64

# %%
EP_Data[EP_Data.duplicated()].shape
# Out:
# (41, 5)

# %%
import plotly.express as px
fig = px.histogram(EP_Data,
                   x='energy_production',
                   nbins=4,
                   title='Distribution of energy_production')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
correlations = EP_Data.corr(method='pearson')

import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(correlations, cmap="coolwarm", annot=True)
plt.show()

# %%
import plotly.express as px
fig = px.box(EP_Data, y="amb_pressure")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming Salary_test is your DataFrame
columns_Features = [0, 1, 2, 3, 4]  # Adjust column indices as needed

for column in columns_Features:
    plt.figure(figsize=(20, 1))
    sns.boxplot(x=EP_Data.iloc[:, column])
    plt.title(f"Box Plot of {EP_Data.columns[column]}")
    plt.show()

# %%
fig = px.scatter(EP_Data,
                 x='energy_production',
                 y='temperature',
                 title='energy_production V/S temperature', trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(EP_Data,
                 x='energy_production',
                 y='exhaust_vacuum',
                 title='energy_production V/S exhaust_vacuum', trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(EP_Data,
                 x='energy_production',
                 y='amb_pressure',
                 title='energy_production V/S amb_pressure', trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(EP_Data,
                 x='energy_production',
                 y='r_humidity',
                 title='energy_production V/S r_humidity', trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.pairplot(EP_Data)

# %%
# Assuming 'temperature' is the column name in EP_Data
greater = EP_Data[EP_Data['temperature'] >38]
print(greater)

"""Room temperature: 20-25 degrees Celsius
Operational temperatures in power plants or industrial settings:100-1000 degrees Celsius """
# Out:
# Empty DataFrame
# Columns: [temperature, exhaust_vacuum, amb_pressure, r_humidity, energy_production]
# Index: []
# 'Room temperature: 20-25 degrees Celsius\nOperational temperatures in power plants or industrial settings:100-1000 degrees Celsius '

# %%
# Assuming 'amb_pressure' is the column name in EP_Data
greater1 = EP_Data[EP_Data['amb_pressure'] > 1000]
print(greater1)

"""Range at sea level: 900-1100 millibars
Variations with altitude: Decreases by about 1 millibar for every 10-meter increase in altitude.
"""
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9501 rows x 5 columns]
# ...

# %%
# Assuming 'r_humidity' is the column name in EP_Data
greater2 = EP_Data[EP_Data['r_humidity'] > 32.34]
print(greater2)

"""Desert regions: 10-30%
Coastal regions: 60-80%
Indoor environments: 30-60%
"""
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 0            9.59           38.56       1017.01       60.10             481.30
# 1           12.04           42.34       1019.72       94.67             465.36
# 2           13.87           45.08       1024.42       81.69             465.48
# 3           13.72           54.30       1017.89       79.08             467.05
# 4           15.14           49.64       1023.78       75.00             463.58
# ...           ...             ...           ...         ...                ...
# 9563        17.10           49.69       1005.53       81.82             457.32
# 9564        24.73           65.34       1015.42       52.80             446.92
# 9565        30.44           56.24       1005.19       56.24             429.34
# 9566        23.00           66.05       1020.61       80.29             421.57
# 9567        17.75           49.25       1020.86       63.67             454.41
#
# [9547 rows x 5 columns]
# ...

# %%
# Assuming 'energy_production ' is the column name in EP_Data
greater3 = EP_Data[EP_Data['energy_production'] > 495]
print(greater3)
"""Small-scale plants:    1-100 MW
Large-scale utility plants: 100-1000+ MW
"""
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 3303         5.15           40.07       1012.27       63.31             495.35
# 4487         5.48           40.07       1019.63       65.62             495.76
# 5118         6.17           40.07       1013.70       58.99             495.21
# 5285         5.41           40.07       1019.16       64.77             495.24
# 9278         5.25           40.07       1019.48       67.70             495.23
# 'Small-scale plants:    1-100 MW\nLarge-scale utility plants: 100-1000+ MW\n'

# %%
# Assuming 'Exhaust Vacuum' is the column name in EP_Data
greater4 = EP_Data[EP_Data['exhaust_vacuum'] > 80]
print(greater4)


"""Low vacuum: Around 50-200 cm Hg
Higher vacuum: Closer to 0 cm Hg (absolute pressure)"""
# Out:
#       temperature  exhaust_vacuum  amb_pressure  r_humidity  energy_production
# 505         30.92           80.18       1010.11       72.47             432.35
# 1321        28.59           80.18       1011.36       89.18             431.55
# 3930        22.89           80.25       1006.38       80.25             446.15
# 5734        33.95           80.18       1010.30       56.69             432.22
# 5923        21.37           81.56       1006.57       81.56             434.38
# 6182        33.30           80.18       1011.09       63.98             430.16
# 8218        33.67           80.18       1010.83       60.87             431.99
# 'Low vacuum: Around 50-200 cm Hg\nHigher vacuum: Closer to 0 cm Hg (absolute pressure)'

# %% [markdown]
# #MLR model
#
# > Indented block

# %%
import statsmodels.formula.api as smf
model = smf.ols("energy_production~temperature+exhaust_vacuum +amb_pressure +r_humidity",data=EP_Data).fit()

# %%
#coefficients
model.params
# Out:
# Intercept         454.609274
# temperature        -1.977513
# exhaust_vacuum     -0.233916
# amb_pressure        0.062083
# r_humidity         -0.158054
# dtype: float64

# %%
#t and p-values
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept          46.633709
# temperature      -129.342024
# exhaust_vacuum    -32.122109
# amb_pressure        6.564086
# r_humidity        -37.918473
# dtype: float64
#  Intercept          0.000000e+00
# temperature        0.000000e+00
# exhaust_vacuum    4.375305e-215
# amb_pressure       5.507109e-11
# r_humidity        3.104584e-293
# dtype: float64

# %%
#R squared values
(model.rsquared,model.rsquared_adj)  # r^2 is Accuraccy of a model and adj_r^2 is if it is increases then variabe is irrilavent
# Out:
# (0.9286960898122537, 0.9286662648994909)

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') #line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid < (-18)))  # It shows which data points are outliers based on the condition (model.resid < (-18))
# Out:
# [array([1339, 1549, 1654, 2144, 2871, 3668, 4568, 5480, 5694, 6237, 7723,
#         8068, 8099, 8724, 9213, 9566])]

# %%
#Residual plot for homoscedasticity it mean the data points are in non-linear
def get_standardized_values( vals ):
    return(vals - vals.mean())/vals.std()   #we are going to normalize the error by useing z-score

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))
plt.title("Residual plot")
plt.xlabel("standardized fitted values")
plt.ylabel("standardized residual values")
plt.show()

# %% [markdown]
# # cook's distance

# %%
model_influence = model.get_influence()
(c,_) = model_influence.cooks_distance

# %%
EP_Data.shape
# Out:
# (9568, 5)

# %%
#plot the influcence values using stem plot
import matplotlib.pyplot as plt
import numpy as np
fig = plt.subplots(figsize=(8, 3))
plt.stem(np.arange(len(EP_Data)),np.round(c, 5)) #c is cooks distance
plt.xlabel("Row index")
plt.ylabel("cooks Distance")
plt.show()

 # so the points which are far from the cook's distance that has to remove because it could be outlers or influence data point

# %%
#let find highest cooks distance value and index data point
#np.index and value of influencer where c is more than .5
(np.argmax(c),np.max(c))  # output which is got that data point has to remove
# Out:
# (8724, 0.01472459396582415)

# %% [markdown]
# # High Influence point

# %%
from statsmodels.graphics.regressionplots import influence_plot
import matplotlib.pyplot as plt

# Assuming 'model' is your fitted regression model

# Create the influence plot and set its figure size directly using subplots
fig, ax = plt.subplots(figsize=(20, 12))
influence_plot(model, ax=ax)

# Show the plot
plt.show()
